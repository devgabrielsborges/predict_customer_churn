# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('../data/raw/test.csv')

# %%
train.shape
# Out:
# (254655, 20)

# %%
train.info()
train.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254655 entries, 0 to 254654
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                254655 non-null  int64
#  1   gender            254655 non-null  object
#  2   SeniorCitizen     254655 non-null  int64
#  3   Partner           254655 non-null  object
#  4   Dependents        254655 non-null  object
#  5   tenure            254655 non-null  int64
#  6   PhoneService      254655 non-null  object
#  7   MultipleLines     254655 non-null  object
#  8   InternetService   254655 non-null  object
#  9   OnlineSecurity    254655 non-null  object
#  10  OnlineBackup      254655 non-null  object
#  11  DeviceProtection  254655 non-null  object
#  12  TechSupport       254655 non-null  object
#  13  StreamingTV       254655 non-null  object
#  14  StreamingMovies   254655 non-null  object
#  15  Contract          254655 non-null  object
# ...

# %%
train.head(10)
# Out:
#        id  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  594194  Female              0     Yes         No      72          Yes
# 1  594195  Female              0     Yes         No      71          Yes
# 2  594196    Male              0      No         No      12          Yes
# 3  594197    Male              0     Yes        Yes      71          Yes
# 4  594198  Female              0      No         No      15          Yes
# 5  594199    Male              0      No         No      24          Yes
# 6  594200  Female              0      No         No       1          Yes
# 7  594201  Female              0      No        Yes      67          Yes
# 8  594202  Female              0     Yes         No      55          Yes
# 9  594203  Female              0      No         No      50          Yes
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0           Yes     Fiber optic                  Yes                  Yes
# ...

# %%
train.isnull().sum()
# Out:
# id                  0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# dtype: int64

# %%
train[["gender", "Dependents", "InternetService", "PaymentMethod"]] = train[["gender", "Dependents", "InternetService", "PaymentMethod"]].astype("string")
train[["Partner", "PhoneService", "MultipleLines", "OnlineSecurity", "DeviceProtection", "TechSupport", "StreamingTV", "StreamingMovies", "Contract", "PaperlessBilling"]] = train[["Partner", "PhoneService", "MultipleLines", "OnlineSecurity", "DeviceProtection", "TechSupport", "StreamingTV", "StreamingMovies", "Contract", "PaperlessBilling"]].astype("category")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254655 entries, 0 to 254654
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                254655 non-null  int64
#  1   gender            254655 non-null  string
#  2   SeniorCitizen     254655 non-null  int64
#  3   Partner           254655 non-null  category
#  4   Dependents        254655 non-null  string
#  5   tenure            254655 non-null  int64
#  6   PhoneService      254655 non-null  category
#  7   MultipleLines     254655 non-null  category
#  8   InternetService   254655 non-null  string
#  9   OnlineSecurity    254655 non-null  category
#  10  OnlineBackup      254655 non-null  object
#  11  DeviceProtection  254655 non-null  category
#  12  TechSupport       254655 non-null  category
#  13  StreamingTV       254655 non-null  category
#  14  StreamingMovies   254655 non-null  category
# ...

# %%
train.to_csv('../data/raw/test.csv', index=False)
